# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("../data/original/final_matches.csv")

# %%
df.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'opp formation', 'referee', 'match report', 'notes', 'sh', 'sot',
#        'dist', 'fk', 'pk', 'pkatt', 'team', 'season'],
#       dtype='object')

# %%
column_order = ['date', 'time', 'round','team', 'opponent', 'venue' ,'gf', 'ga', 'result', 'formation', 'opp formation', 'poss','xg', 'xga', 'sh', 'sot', 'dist', 'season']

# %%
df = df[column_order] # Reorder columns

# %%
team = list(df['team'].unique()) # Get unqiue team names

# %%
opponent = list(df['opponent'].unique()) # Get unique opponent names
opponent.sort()

# %%
set(team).symmetric_difference(set(opponent)) # Find teams present in one list and not in the other
# Some teams are named differently
# Out:
# {'Brighton',
#  'Brighton And Hove Albion',
#  'Manchester United',
#  'Manchester Utd',
#  'Newcastle United',
#  'Newcastle Utd',
#  "Nott'ham Forest",
#  'Nottingham Forest',
#  'Sheffield United',
#  'Sheffield Utd',
#  'Tottenham',
#  'Tottenham Hotspur',
#  'West Brom',
#  'West Bromwich Albion',
#  'West Ham',
#  'West Ham United',
#  'Wolverhampton Wanderers',
#  'Wolves'}

# %%
team_names = dict(zip(team, opponent))

# %%
df['team'] = df['team'].apply(lambda x: team_names[x])

# %%
df['team'].unique()
# Out:
# array(['Arsenal', 'Aston Villa', 'Bournemouth', 'Brentford', 'Brighton',
#        'Burnley', 'Chelsea', 'Crystal Palace', 'Everton', 'Fulham',
#        'Ipswich Town', 'Leeds United', 'Leicester City', 'Liverpool',
#        'Luton Town', 'Manchester City', 'Manchester Utd', 'Newcastle Utd',
#        'Norwich City', "Nott'ham Forest", 'Sheffield Utd', 'Southampton',
#        'Tottenham', 'Watford', 'West Brom', 'West Ham', 'Wolves'],
#       dtype=object)

# %%
df
# Out:
#             date   time         round     team         opponent venue  gf  ga  \
# 0     2020-09-12  12:30   Matchweek 1  Arsenal           Fulham  Away   3   0
# 1     2020-09-19  20:00   Matchweek 2  Arsenal         West Ham  Home   2   1
# 2     2020-09-28  20:00   Matchweek 3  Arsenal        Liverpool  Away   1   3
# 3     2020-10-04  14:00   Matchweek 4  Arsenal    Sheffield Utd  Home   2   1
# 4     2020-10-17  17:30   Matchweek 5  Arsenal  Manchester City  Away   0   1
# ...          ...    ...           ...      ...              ...   ...  ..  ..
# 3795  2025-04-26  15:00  Matchweek 34   Wolves   Leicester City  Home   3   0
# 3796  2025-05-02  20:00  Matchweek 35   Wolves  Manchester City  Away   0   1
# 3797  2025-05-10  15:00  Matchweek 36   Wolves         Brighton  Home   0   2
# 3798  2025-05-20  20:00  Matchweek 37   Wolves   Crystal Palace  Away   2   4
# 3799  2025-05-25  16:00  Matchweek 38   Wolves        Brentford  Home   1   1
#
#      result formation opp formation  poss   xg  xga    sh  sot  dist  season
# 0         W     3-4-3       4-2-3-1  54.0  1.9  0.1  13.0  5.0  14.1    2021
# 1         W     3-4-3         5-4-1  62.0  1.1  2.0   7.0  3.0  14.8    2021
# 2         L     3-4-3         4-3-3  34.0  1.3  2.7   4.0  3.0  15.0    2021
# 3         W     4-3-3         3-5-2  64.0  0.6  0.2   6.0  5.0  16.3    2021
# 4         L     4-3-3       3-1-4-2  42.0  0.9  1.3  11.0  3.0  18.4    2021
# ...     ...       ...           ...   ...  ...  ...   ...  ...   ...     ...
# 3795      W     3-4-3       4-2-3-1  56.0  2.0  1.1  20.0  5.0  19.8    2025
# 3796      L     3-4-3       4-2-3-1  37.0  0.4  0.7   6.0  0.0  16.3    2025
# 3797      L     3-4-3       4-2-3-1  56.0  0.9  1.6  10.0  3.0  15.5    2025
# 3798      L     3-4-3         3-4-3  69.0  1.4  1.7  12.0  3.0  15.1    2025
# 3799      D     3-4-3       4-2-3-1  49.0  1.0  1.4  18.0  6.0  20.6    2025
#
# [3800 rows x 18 columns]

# %%
df_home = df[df['venue'] == 'Home'].sort_values(by=['date','time']).reset_index(drop=True)
df_away = df[df['venue'] == 'Away'].sort_values(by=['date','time']).reset_index(drop=True)

# %%
df_away.rename(
    columns={"team": "away_team",
             "opponent": "home_team",
             "formation": "away_formation",
             "opp formation": "home_formation",
             "gf": "away_goals",
             "ga": "home_goals",
             "poss": "away_poss",
             "xg": "away_xg",
             "xga": "home_xg",
             "sh": "away_sh",
             "sot": "away_shot_on_target",
             "dist": "away_dist_covered"},
             inplace=True
)

# %%
df_home.rename(
    columns={"team": "home_team",
             "opponent": "away_team",
             "formation": "home_formation",
             "opp formation": "away_formation",
             "gf": "home_goals",
             "ga": "away_goals",
             "poss": "home_poss",
             "xg": "home_xg",
             "xga": "away_xg",
             "sh": "home_sh",
             "sot": "home_shot_on_target",
             "dist": "home_dist_covered"},
             inplace=True
)

# %%
away_stats_to_add = df_away[['date', 'home_team', 'away_team', 'away_sh', 'away_shot_on_target', 'away_dist_covered', 'away_poss']].copy()

fixtures_df = pd.merge(df_home, away_stats_to_add, on=['date', 'home_team', 'away_team'])

new_order = [
    'date', 'time', 'round', 'home_team', 'away_team', 'venue', 
    'result', 'home_goals', 'away_goals', 
    'home_poss', 'away_poss',
    'home_xg', 'away_xg',
    'home_sh', 'away_sh',
    'home_shot_on_target', 'away_shot_on_target',
    'home_dist_covered', 'away_dist_covered',
    'home_formation', 'away_formation', 'season',
]

fixtures_df = fixtures_df[new_order]

fixtures_df.columns
# Out:
# Index(['date', 'time', 'round', 'home_team', 'away_team', 'venue', 'result',
#        'home_goals', 'away_goals', 'home_poss', 'away_poss', 'home_xg',
#        'away_xg', 'home_sh', 'away_sh', 'home_shot_on_target',
#        'away_shot_on_target', 'home_dist_covered', 'away_dist_covered',
#        'home_formation', 'away_formation', 'season'],
#       dtype='object')

# %%
fixtures_df
# Out:
#             date   time         round        home_team       away_team venue  \
# 0     2020-09-12  12:30   Matchweek 1           Fulham         Arsenal  Home
# 1     2020-09-12  15:00   Matchweek 1   Crystal Palace     Southampton  Home
# 2     2020-09-12  17:30   Matchweek 1        Liverpool    Leeds United  Home
# 3     2020-09-12  20:00   Matchweek 1         West Ham   Newcastle Utd  Home
# 4     2020-09-13  14:00   Matchweek 1        West Brom  Leicester City  Home
# ...          ...    ...           ...              ...             ...   ...
# 1895  2025-05-25  16:00  Matchweek 38    Newcastle Utd         Everton  Home
# 1896  2025-05-25  16:00  Matchweek 38  Nott'ham Forest         Chelsea  Home
# 1897  2025-05-25  16:00  Matchweek 38      Southampton         Arsenal  Home
# 1898  2025-05-25  16:00  Matchweek 38        Tottenham        Brighton  Home
# 1899  2025-05-25  16:00  Matchweek 38           Wolves       Brentford  Home
#
#      result  home_goals  away_goals  home_poss  away_poss  home_xg  away_xg  \
# 0         L           0           3       46.0       54.0      0.1      1.9
# 1         W           1           0       31.0       69.0      1.1      0.9
# 2         W           4           3       49.0       51.0      2.7      0.3
# 3         L           0           2       58.0       42.0      1.0      1.6
# 4         L           0           3       36.0       64.0      0.4      2.8
# ...     ...         ...         ...        ...        ...      ...      ...
# 1895      L           0           1       65.0       35.0      1.2      1.2
# 1896      L           0           1       52.0       48.0      1.2      1.1
# 1897      L           1           2       38.0       62.0      0.6      2.3
# 1898      L           1           4       34.0       66.0      2.0      2.2
# 1899      D           1           1       49.0       51.0      1.0      1.4
#
#       home_sh  away_sh  home_shot_on_target  away_shot_on_target  \
# 0         5.0     13.0                  2.0                  5.0
# 1         5.0      9.0                  3.0                  5.0
# 2        20.0      6.0                  4.0                  3.0
# 3        15.0     15.0                  3.0                  2.0
# 4         7.0     11.0                  1.0                  5.0
# ...       ...      ...                  ...                  ...
# 1895     17.0     14.0                  6.0                  6.0
# 1896     10.0      6.0                  2.0                  2.0
# 1897      7.0     23.0                  2.0                  7.0
# 1898      3.0     22.0                  1.0                  7.0
# 1899     18.0     13.0                  6.0                  7.0
#
#       home_dist_covered  away_dist_covered home_formation away_formation  \
# 0                  25.1               14.1        4-2-3-1          3-4-3
# 1                  10.6               15.3          4-4-2          4-4-2
# 2                  18.4               19.9          4-3-3        4-1-4-1
# 3                  16.5               17.6        4-2-3-1          4-4-2
# 4                  18.4               19.3          5-4-1        4-1-4-1
# ...                 ...                ...            ...            ...
# 1895               17.3               18.5          3-4-3        4-2-3-1
# 1896               14.0               14.3        4-3-1-2        4-2-3-1
# 1897               16.3               15.9          5-4-1        4-2-3-1
# 1898               17.1               15.4          4-3-3          4-4-2
# 1899               20.6               14.4          3-4-3        4-2-3-1
#
#       season
# 0       2021
# 1       2021
# 2       2021
# 3       2021
# 4       2021
# ...      ...
# 1895    2025
# 1896    2025
# 1897    2025
# 1898    2025
# 1899    2025
#
# [1900 rows x 22 columns]

# %%
fixtures_df.index = fixtures_df['date']
fixtures_df.drop(columns=['date'], inplace=True)

# %%
fixtures_df
# Out:
#              time         round        home_team       away_team venue result  \
# date
# 2020-09-12  12:30   Matchweek 1           Fulham         Arsenal  Home      L
# 2020-09-12  15:00   Matchweek 1   Crystal Palace     Southampton  Home      W
# 2020-09-12  17:30   Matchweek 1        Liverpool    Leeds United  Home      W
# 2020-09-12  20:00   Matchweek 1         West Ham   Newcastle Utd  Home      L
# 2020-09-13  14:00   Matchweek 1        West Brom  Leicester City  Home      L
# ...           ...           ...              ...             ...   ...    ...
# 2025-05-25  16:00  Matchweek 38    Newcastle Utd         Everton  Home      L
# 2025-05-25  16:00  Matchweek 38  Nott'ham Forest         Chelsea  Home      L
# 2025-05-25  16:00  Matchweek 38      Southampton         Arsenal  Home      L
# 2025-05-25  16:00  Matchweek 38        Tottenham        Brighton  Home      L
# 2025-05-25  16:00  Matchweek 38           Wolves       Brentford  Home      D
#
#             home_goals  away_goals  home_poss  away_poss  home_xg  away_xg  \
# date
# 2020-09-12           0           3       46.0       54.0      0.1      1.9
# 2020-09-12           1           0       31.0       69.0      1.1      0.9
# 2020-09-12           4           3       49.0       51.0      2.7      0.3
# 2020-09-12           0           2       58.0       42.0      1.0      1.6
# 2020-09-13           0           3       36.0       64.0      0.4      2.8
# ...                ...         ...        ...        ...      ...      ...
# 2025-05-25           0           1       65.0       35.0      1.2      1.2
# 2025-05-25           0           1       52.0       48.0      1.2      1.1
# 2025-05-25           1           2       38.0       62.0      0.6      2.3
# 2025-05-25           1           4       34.0       66.0      2.0      2.2
# 2025-05-25           1           1       49.0       51.0      1.0      1.4
#
#             home_sh  away_sh  home_shot_on_target  away_shot_on_target  \
# date
# 2020-09-12      5.0     13.0                  2.0                  5.0
# 2020-09-12      5.0      9.0                  3.0                  5.0
# 2020-09-12     20.0      6.0                  4.0                  3.0
# 2020-09-12     15.0     15.0                  3.0                  2.0
# 2020-09-13      7.0     11.0                  1.0                  5.0
# ...             ...      ...                  ...                  ...
# 2025-05-25     17.0     14.0                  6.0                  6.0
# 2025-05-25     10.0      6.0                  2.0                  2.0
# 2025-05-25      7.0     23.0                  2.0                  7.0
# 2025-05-25      3.0     22.0                  1.0                  7.0
# 2025-05-25     18.0     13.0                  6.0                  7.0
#
#             home_dist_covered  away_dist_covered home_formation  \
# date
# 2020-09-12               25.1               14.1        4-2-3-1
# 2020-09-12               10.6               15.3          4-4-2
# 2020-09-12               18.4               19.9          4-3-3
# 2020-09-12               16.5               17.6        4-2-3-1
# 2020-09-13               18.4               19.3          5-4-1
# ...                       ...                ...            ...
# 2025-05-25               17.3               18.5          3-4-3
# 2025-05-25               14.0               14.3        4-3-1-2
# 2025-05-25               16.3               15.9          5-4-1
# 2025-05-25               17.1               15.4          4-3-3
# 2025-05-25               20.6               14.4          3-4-3
#
#            away_formation  season
# date
# 2020-09-12          3-4-3    2021
# 2020-09-12          4-4-2    2021
# 2020-09-12        4-1-4-1    2021
# 2020-09-12          4-4-2    2021
# 2020-09-13        4-1-4-1    2021
# ...                   ...     ...
# 2025-05-25        4-2-3-1    2025
# 2025-05-25        4-2-3-1    2025
# 2025-05-25        4-2-3-1    2025
# 2025-05-25          4-4-2    2025
# 2025-05-25        4-2-3-1    2025
#
# [1900 rows x 21 columns]

# %%
df_2020_2021 = fixtures_df[fixtures_df['season'] == 2021]
df_2021_2022 = fixtures_df[fixtures_df['season'] == 2022]
df_2022_2023 = fixtures_df[fixtures_df['season'] == 2023]
df_2023_2024 = fixtures_df[fixtures_df['season'] == 2024]
df_2024_2025 = fixtures_df[fixtures_df['season'] == 2025]

# %%
df_2024_2025
# Out:
#              time         round        home_team    away_team venue result  \
# date
# 2024-08-16  20:00   Matchweek 1   Manchester Utd       Fulham  Home      W
# 2024-08-17  12:30   Matchweek 1     Ipswich Town    Liverpool  Home      L
# 2024-08-17  15:00   Matchweek 1          Arsenal       Wolves  Home      W
# 2024-08-17  15:00   Matchweek 1          Everton     Brighton  Home      L
# 2024-08-17  15:00   Matchweek 1    Newcastle Utd  Southampton  Home      W
# ...           ...           ...              ...          ...   ...    ...
# 2025-05-25  16:00  Matchweek 38    Newcastle Utd      Everton  Home      L
# 2025-05-25  16:00  Matchweek 38  Nott'ham Forest      Chelsea  Home      L
# 2025-05-25  16:00  Matchweek 38      Southampton      Arsenal  Home      L
# 2025-05-25  16:00  Matchweek 38        Tottenham     Brighton  Home      L
# 2025-05-25  16:00  Matchweek 38           Wolves    Brentford  Home      D
#
#             home_goals  away_goals  home_poss  away_poss  home_xg  away_xg  \
# date
# 2024-08-16           1           0       55.0       45.0      2.4      0.4
# 2024-08-17           0           2       38.0       62.0      0.5      2.6
# 2024-08-17           2           0       53.0       47.0      1.2      0.5
# 2024-08-17           0           3       40.0       60.0      0.5      1.4
# 2024-08-17           1           0       23.0       77.0      0.3      1.8
# ...                ...         ...        ...        ...      ...      ...
# 2025-05-25           0           1       65.0       35.0      1.2      1.2
# 2025-05-25           0           1       52.0       48.0      1.2      1.1
# 2025-05-25           1           2       38.0       62.0      0.6      2.3
# 2025-05-25           1           4       34.0       66.0      2.0      2.2
# 2025-05-25           1           1       49.0       51.0      1.0      1.4
#
#             home_sh  away_sh  home_shot_on_target  away_shot_on_target  \
# date
# 2024-08-16     14.0     10.0                  5.0                  2.0
# 2024-08-17      7.0     18.0                  2.0                  5.0
# 2024-08-17     18.0      9.0                  6.0                  3.0
# 2024-08-17      9.0     10.0                  1.0                  5.0
# 2024-08-17      3.0     19.0                  1.0                  3.0
# ...             ...      ...                  ...                  ...
# 2025-05-25     17.0     14.0                  6.0                  6.0
# 2025-05-25     10.0      6.0                  2.0                  2.0
# 2025-05-25      7.0     23.0                  2.0                  7.0
# 2025-05-25      3.0     22.0                  1.0                  7.0
# 2025-05-25     18.0     13.0                  6.0                  7.0
#
#             home_dist_covered  away_dist_covered home_formation  \
# date
# 2024-08-16               17.6               16.9        4-2-3-1
# 2024-08-17               16.0               14.8        4-2-3-1
# 2024-08-17               17.3               19.3          4-3-3
# 2024-08-17               18.4               13.8        4-2-3-1
# 2024-08-17               13.2               17.0          4-3-3
# ...                       ...                ...            ...
# 2025-05-25               17.3               18.5          3-4-3
# 2025-05-25               14.0               14.3        4-3-1-2
# 2025-05-25               16.3               15.9          5-4-1
# 2025-05-25               17.1               15.4          4-3-3
# 2025-05-25               20.6               14.4          3-4-3
#
#            away_formation  season
# date
# 2024-08-16        4-2-3-1    2025
# 2024-08-17        4-2-3-1    2025
# 2024-08-17        4-2-3-1    2025
# 2024-08-17        4-2-3-1    2025
# 2024-08-17          3-5-2    2025
# ...                   ...     ...
# 2025-05-25        4-2-3-1    2025
# 2025-05-25        4-2-3-1    2025
# 2025-05-25        4-2-3-1    2025
# 2025-05-25          4-4-2    2025
# 2025-05-25        4-2-3-1    2025
#
# [380 rows x 21 columns]

# %%
df_2020_2021.to_csv("../data/processed/2020-2021.csv")
df_2021_2022.to_csv("../data/processed/2021-2022.csv")
df_2022_2023.to_csv("../data/processed/2022-2023.csv")
df_2023_2024.to_csv("../data/processed/2023-2024.csv")
df_2024_2025.to_csv("../data/processed/2024-2025.csv")
